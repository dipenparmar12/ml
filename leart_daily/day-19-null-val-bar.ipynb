# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/stack-overflow-survey-2023/survey_results_public.csv', index_col='ResponseId')

# %%
def plot_nas(df: pd.DataFrame):
    if df.isnull().sum().sum() != 0:
        na_df = (df.isnull().sum() / len(df)) * 100      
        na_df = na_df.drop(na_df[na_df == 0].index).sort_values(ascending=False)
        missing_data = pd.DataFrame({'Missing Ratio %' :na_df})
        missing_data.plot(kind = "barh")
        plt.show()
    else:
        print('No NAs found')
plot_nas(df)

# %%
na_df = (df.isnull().sum() / len(df)) * 100
na_df.sort_values(ascending=False)
# Out:
# AINextVery similar                     97.061132
# AINextSomewhat similar                 93.005472
# AINextNeither different nor similar    92.600691
# AINextVery different                   85.803507
# AIDevWantToWorkWith                    78.037540
#                                          ...
# Country                                 1.357867
# AISelect                                1.357867
# MainBranch                              0.000000
# Age                                     0.000000
# Q120                                    0.000000
# Length: 83, dtype: float64

# %%
na_df[na_df == 0].index
# Out:
# Index(['Q120', 'MainBranch', 'Age'], dtype='object')
