# %% [markdown]
#  - https://youtu.be/roTZJaxjnJc?si=VYrJW7YRZ8o68GV9
#  - https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day17-api-to-dataframe

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page="
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYzEzNWE4N2Q2Yzg3MjEzOTY2NGE0Y2IwMWQ1YzljOSIsInN1YiI6IjY1Njc1Mjk4ODlkOTdmMDBmZTdjYzMzMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.PsiUFjqax4mlqmEm63rin7IM4jk6P4h6Pt7x8maTeM0"
}


df = pd.DataFrame()

for page_no in range(1,10):
    response = requests.get(url+str(page_no), headers=headers)
    data = response.json()
    # print(data)
    df_chunk = pd.DataFrame(data['results'])
    df = pd.concat([df,df_chunk], ignore_index=True)

# df

# %%
required_cols = ['id', 'title', 'popularity','release_date', 'vote_average', 'vote_count', 'overview']
df = df[required_cols]
df
# Out:
#          id                                              title  popularity  \
# 0       238                                      The Godfather     160.639
# 1       278                           The Shawshank Redemption     137.689
# 2       240                              The Godfather Part II      82.973
# 3       424                                   Schindler's List      83.051
# 4     19404                        Dilwale Dulhania Le Jayenge      44.336
# ..      ...                                                ...         ...
# 175     666                                    Central Station      13.891
# 176     600                                  Full Metal Jacket      40.105
# 177  532067  KONOSUBA – God's blessing on this wonderful wo...      27.844
# 178   37165                                    The Truman Show      67.046
# 179  664767          Mortal Kombat Legends: Scorpion's Revenge      75.781
#
#     release_date  vote_average  vote_count  \
# ...

# %%
df.to_csv('day-17-api-top-movies.csv')
